# %%
#from sklearn.Linear_model import LinearRegression
import numpy as np

x=np.array([[1],[2],[3],[4]])
print(x)
y=([1,4,7])
print(y)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]]
# [1, 4, 7]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\preethi\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\preethi\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\preethi\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\preethi\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\preethi\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x=np.array([[1],[2],[3],[4]])
print(x)
y=([1,4,7,8])
print(y)

model=LinearRegression()
model.fit(x,y)
print(model.predict([[3]]))
# Out:
# [[1]
#  [2]
#  [3]
#  [4]]
# [1, 4, 7, 8]
# [6.2]
